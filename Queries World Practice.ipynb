# %% [markdown]
# # 1
# ![image.png](attachment:9a7b6aee-28ff-494d-9319-2a5b269497e5.png)

# %% [markdown]
# # 2
# ![image.png](attachment:d794bcc3-4e44-4a3d-8b1c-8c63c3d5de76.png)

# %% [markdown]
# # 3
# ![image.png](attachment:c44c2921-3b1e-43a8-a930-8e04c094e04b.png)

# %% [markdown]
# # 4
# ![image.png](attachment:115a15cc-9fcc-47dd-be8a-79b8cb3c704e.png)

# %% [markdown]
# # 5
# ![image.png](attachment:673e15e5-7f4c-429c-ac0d-2e16379373b2.png)

# %% [markdown]
# # 6
# ![image.png](attachment:82245057-bdc9-4849-9c36-416f0ab69936.png)

# %% [markdown]
# # 7
# ![image.png](attachment:c0944a56-44bd-48b3-97b2-a422c2fe4b46.png)

# %% [markdown]
# # 8
# ![image.png](attachment:acb027cd-c501-44d1-aa79-c36fde01aac7.png)
