# %% [markdown]
# # 1
# ![image.png](attachment:1d4611a7-bc0f-459c-8f83-718e75a07f62.png)

# %% [markdown]
# # 2
# ![image.png](attachment:6d0a686a-68f5-4930-a47b-cc396bf64294.png)

# %% [markdown]
# # 3
# ![image.png](attachment:8d256b58-8b6b-4e94-b3a1-f4ea8b8e675b.png)

# %% [markdown]
# # 4
# ![image.png](attachment:25e16085-ba67-4280-8aba-4df8af3be356.png)

# %% [markdown]
# # 5
# ![image.png](attachment:f1481547-eeb8-48ca-a8ee-47422c8756df.png)

# %% [markdown]
# # 6
# ![image.png](attachment:39828544-6392-4ea3-8c63-77b83362d3f3.png)

# %% [markdown]
# # 7
# ![image.png](attachment:124055b1-694f-47c2-b4be-577928147aff.png)
